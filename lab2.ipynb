# %% [markdown]
# # Lab 2

# %% [markdown]
# The first step in the lab is to import our data and the required libraries. First, we remove the warnings and import pandas. Then we pull the data from our S3.

# %%
import warnings

warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia-340-fall-lev/NCHS_-_Drug_Poisoning_Mortality_by_State__United_States.csv')
df.head()
# Out:
#            State  Year         Sex Age Group Race and Hispanic Origin  Deaths  \
# 0  United States  2003  Both Sexes     15–24                 Hispanic     226
# 1        Alabama  1999  Both Sexes  All Ages    All Races-All Origins     169
# 2        Alabama  2000  Both Sexes  All Ages    All Races-All Origins     197
# 3        Alabama  2001  Both Sexes  All Ages    All Races-All Origins     216
# 4        Alabama  2002  Both Sexes  All Ages    All Races-All Origins     211
#
#    Population  Crude Death Rate  Standard Error for Crude Rate  \
# 0     7255772            3.1148                        0.20719
# 1     4430143            3.8148                        0.29344
# 2     4447100            4.4299                        0.31561
# 3     4467634            4.8348                        0.32896
# 4     4480089            4.7097                        0.32423
#
#    Low Confidence Limit for Crude Rate  Upper Confidence Limit for Crude Rate  \
# ...

# %% [markdown]
# ## View

# %% [markdown]
# As you can see below, the view functions in python allow us to see that we have a total of 19 columns and 3180 rows/entrys. This dataset includes both numeric and text columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3180 entries, 0 to 3179
# Data columns (total 19 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   State                                         3180 non-null   object
#  1   Year                                          3180 non-null   int64
#  2   Sex                                           3180 non-null   object
#  3   Age Group                                     3180 non-null   object
#  4   Race and Hispanic Origin                      3180 non-null   object
#  5   Deaths                                        3180 non-null   int64
#  6   Population                                    3180 non-null   int64
#  7   Crude Death Rate                              3180 non-null   float64
#  8   Standard Error for Crude Rate                 3180 non-null   float64
# ...

# %%
df.describe()
# Out:
#               Year        Deaths    Population  Crude Death Rate  \
# count  3180.000000   3180.000000  3.180000e+03       3180.000000
# mean   2008.500000   2154.529245  1.677489e+07         11.644390
# std       5.767188   5345.736615  3.480532e+07          9.961261
# min    1999.000000      1.000000  2.381630e+05          0.038900
# 25%    2003.750000    134.000000  2.762571e+06          4.088650
# 50%    2008.500000    522.000000  6.517268e+06          9.626500
# 75%    2013.250000   1705.750000  1.835934e+07         15.963425
# max    2018.000000  70237.000000  3.271674e+08         76.039600
#
#        Standard Error for Crude Rate  Low Confidence Limit for Crude Rate  \
# count                    3180.000000                          3180.000000
# mean                        0.448524                            10.782035
# std                         0.342431                             9.682106
# min                         0.014280                             0.008000
# ...

# %%
df.shape
# Out:
# (3180, 19)

# %%
df.sort_values(by='Deaths')
# Out:
#               State  Year         Sex Age Group Race and Hispanic Origin  \
# 2640  United States  1999        Male       75+                 Hispanic
# 1781  United States  2000      Female      0–14                 Hispanic
# 2515  United States  2014        Male      0–14                 Hispanic
# 1780  United States  1999      Female      0–14                 Hispanic
# 1785  United States  2004      Female      0–14                 Hispanic
# ...             ...   ...         ...       ...                      ...
# 1061  United States  2015  Both Sexes  All Ages    All Races-All Origins
# 1598  United States  2017  Both Sexes  All Ages       Non-Hispanic White
# 1062  United States  2016  Both Sexes  All Ages    All Races-All Origins
# 1064  United States  2018  Both Sexes  All Ages    All Races-All Origins
# 1063  United States  2017  Both Sexes  All Ages    All Races-All Origins
#
#       Deaths  Population  Crude Death Rate  Standard Error for Crude Rate  \
# ...

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# Below we used some common data cleaning PANDAS functions. First, we dropped any blank values, then we chose a column to rename. I chose to change "Unit" to "Unit of Measure" simply because I wanted to make sure I could and the previous names were already good.

# %%
df = df.dropna()
df.isnull().sum()
df = df.rename(columns={'Unit': 'Unit of Measure'})
df.head()
# Out:
#      State  Year         Sex Age Group Race and Hispanic Origin  Deaths  \
# 1  Alabama  1999  Both Sexes  All Ages    All Races-All Origins     169
# 2  Alabama  2000  Both Sexes  All Ages    All Races-All Origins     197
# 3  Alabama  2001  Both Sexes  All Ages    All Races-All Origins     216
# 4  Alabama  2002  Both Sexes  All Ages    All Races-All Origins     211
# 5  Alabama  2003  Both Sexes  All Ages    All Races-All Origins     197
#
#    Population  Crude Death Rate  Standard Error for Crude Rate  \
# 1     4430143            3.8148                        0.29344
# 2     4447100            4.4299                        0.31561
# 3     4467634            4.8348                        0.32896
# 4     4480089            4.7097                        0.32423
# 5     4503491            4.3744                        0.31166
#
#    Low Confidence Limit for Crude Rate  Upper Confidence Limit for Crude Rate  \
# ...

# %% [markdown]
# ## Manipulate the Data

# %% [markdown]
# First, I selected just one column "Deaths". I then sorted the Crude Death Rate by ascending order. After that, I experimented with the splice function, showing rows 24-34. Lastly, I filtered the death column by obnly deaths above 100.

# %%
df['Deaths']
# Out:
# 1       169
# 2       197
# 3       216
# 4       211
# 5       197
#        ...
# 3175    109
# 3176     96
# 3177     99
# 3178     69
# 3179     66
# Name: Deaths, Length: 1260, dtype: int64

# %%
df.sort_values('Crude Death Rate')
# Out:
#                      State  Year         Sex Age Group  \
# 1941         United States  2000      Female  All Ages
# 302                   Iowa  1999  Both Sexes  All Ages
# 689           North Dakota  2005  Both Sexes  All Ages
# 683           North Dakota  1999  Both Sexes  All Ages
# 1942         United States  2001      Female  All Ages
# ...                    ...   ...         ...       ...
# 721                   Ohio  2017  Both Sexes  All Ages
# 179   District of Columbia  2017  Both Sexes  All Ages
# 3139         West Virginia  2018  Both Sexes  All Ages
# 3137         West Virginia  2016  Both Sexes  All Ages
# 3138         West Virginia  2017  Both Sexes  All Ages
#
#      Race and Hispanic Origin  Deaths  Population  Crude Death Rate  \
# 1941                 Hispanic     290    17144023            1.6916
# 302     All Races-All Origins      53     2917637            1.8165
# 689     All Races-All Origins      12      646089            1.8573
# ...

# %%
df[24:34]
# Out:
#      State  Year         Sex Age Group Race and Hispanic Origin  Deaths  \
# 25  Alaska  2003  Both Sexes  All Ages    All Races-All Origins      83
# 26  Alaska  2004  Both Sexes  All Ages    All Races-All Origins      86
# 27  Alaska  2005  Both Sexes  All Ages    All Races-All Origins      79
# 28  Alaska  2006  Both Sexes  All Ages    All Races-All Origins      76
# 29  Alaska  2007  Both Sexes  All Ages    All Races-All Origins      72
# 30  Alaska  2008  Both Sexes  All Ages    All Races-All Origins     127
# 31  Alaska  2009  Both Sexes  All Ages    All Races-All Origins     131
# 32  Alaska  2010  Both Sexes  All Ages    All Races-All Origins      83
# 33  Alaska  2011  Both Sexes  All Ages    All Races-All Origins     107
# 34  Alaska  2012  Both Sexes  All Ages    All Races-All Origins     129
#
#     Population  Crude Death Rate  Standard Error for Crude Rate  \
# 25      648414           12.8005                        1.40503
# ...

# %%
df = df[(df['Deaths']>=100)]
df.describe()
# Out:
#               Year        Deaths    Population  Crude Death Rate  \
# count  1107.000000   1107.000000  1.107000e+03       1107.000000
# mean   2008.921409   3434.121048  2.671532e+07         13.320163
# std       5.694939   8216.516242  5.536985e+07          7.075086
# min    1999.000000    101.000000  5.685020e+05          1.691600
# 25%    2004.000000    354.500000  3.056763e+06          8.513900
# 50%    2009.000000    777.000000  6.175727e+06         11.981600
# 75%    2014.000000   1870.500000  1.913247e+07         16.167950
# max    2018.000000  70237.000000  3.271674e+08         53.638600
#
#        Standard Error for Crude Rate  Low Confidence Limit for Crude Rate  \
# count                    1107.000000                          1107.000000
# mean                        0.498347                            12.343404
# std                         0.372193                             6.697772
# min                         0.046520                             1.496900
# ...
